# %%
import tushare as ts
import pandas as pd
import datetime
import numpy as np
import matplotlib.pyplot as plt

ts.set_token('303f0dbbabfad0fd3f9465368bdc62fc775bde6711d6b59c2ca10109')
pro = ts.pro_api()

stocks = ['600048.SH', '600690.SH', '601901.SH', '601668.SH', '600585.SH', '600031.SH',
 '600029.SH', '603993.SH', '600050.SH', '601888.SH', '600104.SH', '600309.SH',
 '600036.SH', '600030.SH','601138.SH', '600019.SH', '600519.SH','600183.SH',
 '600741.SH', '601318.SH']

equity = []
day = []
for stock in stocks:
    df=pro.daily_basic(ts_code=stock,start_date='20200101',end_date='20200228')
    equity.append(df.total_mv.values)
    day.append(list(df.trade_date.values))
equity = np.array(equity).sum(axis=0)
        
    
day = pd.to_datetime(day[0])
DF = pd.DataFrame()
DF['equity'] = equity
DF = DF.set_index(day)
fig, ax = plt.subplots(figsize=(20,8))
fig.subplots_adjust(bottom=0.3)
plt.xticks(rotation=90)
plt.plot(DF)
# Out:
# C:\Users\stellajin\Anaconda3\lib\site-packages\pandas\plotting\_converter.py:129: FutureWarning: Using an implicitly registered datetime converter for a matplotlib plotting method. The converter was registered by pandas on import. Future versions of pandas will require you to explicitly register matplotlib converters.
#
# To register the converters:
# 	>>> from pandas.plotting import register_matplotlib_converters
# 	>>> register_matplotlib_converters()
#   warnings.warn(msg, FutureWarning)
